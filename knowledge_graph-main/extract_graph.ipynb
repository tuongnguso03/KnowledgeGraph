# %% [markdown]
# ## Setup

# %%
pip install yachalk
# Out:
# Requirement already satisfied: yachalk in d:\knowledgegraph\kg_venv\lib\site-packages (0.1.5)
# Requirement already satisfied: setuptools in d:\knowledgegraph\kg_venv\lib\site-packages (from yachalk) (65.5.0)
# Requirement already satisfied: importlib-resources in d:\knowledgegraph\kg_venv\lib\site-packages (from yachalk) (6.4.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import os
from langchain.document_loaders import PyPDFLoader, UnstructuredPDFLoader, PyPDFium2Loader
from langchain.document_loaders import PyPDFDirectoryLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
import random

## Input data directory
data_dir = "cureus"
inputdirectory = Path(f"./data_input/{data_dir}")
## This is where the output csv files will be written
out_dir = data_dir
outputdirectory = Path(f"./data_output/{out_dir}")

# %% [markdown]
# ## Load Documents

# %% [markdown]
# ## Create a dataframe of all the chunks

# %%
from docx import Document as Docx
from langchain.schema import Document

def read_docx(file_path):
    doc = Docx(file_path)
    full_text = []
    for paragraph in doc.paragraphs:
        full_text.append(paragraph.text)
    return '\n'.join(full_text)

file_path = '..\Resources\SongHongDoc.docx'
text = read_docx(file_path)
page = Document(page_content=text)

from langchain.text_splitter import TokenTextSplitter

text_splitter = TokenTextSplitter(chunk_size=1024, chunk_overlap=128)

# Only take the first the raw_documents
pages = text_splitter.split_documents([page])


from helpers.df_helpers import documents2Dataframe
df = documents2Dataframe(pages)
print(df.shape)
df.head()
# Out:
# (19, 2)
#                                                 text  \
# 0  Bể trầm tích Sông Hồng là bể trầm tích Kainozo...
# 1  �ng đối tượng, khu vực và nghiên cứu tiềm năng...
# 2  ề tiềm năng còn lại và đề xuất định hướng TKTD...
# 3  �c nước thay đổi từ 30 đến 800m có chỗ trên 10...
# 4  i các Lô 102, 103, 106, 107; mạng lưới tuyến 2...
#
#                            chunk_id
# 0  2b796e4335064983a21222b4251d11e9
# 1  65d47ce81f6f4f298178f626dd46dd9f
# 2  78f3613f808c40b59f9ff520584b8cfe
# 3  917952e0c1434dfaaca1ddcf15bcd9a4
# 4  8c8ea02594854884a84593411403b3c8

# %% [markdown]
# ## Extract Concepts

# %%
## This function uses the helpers/prompt function to extract concepts from text
from helpers.df_helpers import df2Graph
from helpers.df_helpers import graph2Df, generate_OpenAIGPT

# %% [markdown]
# If regenerate is set to True then the dataframes are regenerated and Both the dataframes are written in the csv format so we dont have to calculate them again.
#
#         dfne = dataframe of edges
#
#         df = dataframe of chunks
#
#
# Else the dataframes are read from the output directory

# %%
## To regenerate the graph with LLM, set this to True
regenerate = True

if regenerate:
    concepts_list = df2Graph(df, generate = generate_OpenAIGPT)
    dfg1 = graph2Df(concepts_list)
    if not os.path.exists(outputdirectory):
        os.makedirs(outputdirectory)
    
    dfg1.to_csv(outputdirectory/"graph.csv", sep="|", index=False)
    df.to_csv(outputdirectory/"chunks.csv", sep="|", index=False)
else:
    dfg1 = pd.read_csv(outputdirectory/"graph.csv", sep="|")

dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
## Increasing the weight of the relation to 4. 
## We will assign the weight of 1 when later the contextual proximity will be calculated.  
print(dfg1.shape)
dfg1.head(100)
# Out:
# .[{'node_1': 'Sông Hồng sedimentary basin', 'node_2': 'Kainozoi', 'edge': 'is a type of'}, {'node_1': 'Sông Hồng sedimentary basin', 'node_2': 'petroleum', 'edge': 'contains'}, {'node_1': 'Vietnam Oil and Gas Group', 'node_2': 'Sông Hồng sedimentary basin', 'edge': 'is interested in'}, {'node_1': 'Sông Hồng sedimentary basin', 'node_2': 'Ham Rong discovery', 'edge': 'has'}, {'node_1': 'Sông Hồng sedimentary basin', 'node_2': 'Ki Lan discovery', 'edge': 'has'}, {'node_1': 'Sông Hồng sedimentary basin', 'node_2': 'Blue Whale discovery', 'edge': 'has'}, {'node_1': 'Sông Hồng sedimentary basin', 'node_2': 'Ken Bau gas discovery', 'edge': 'has'}, {'node_1': 'Ham Rong discovery', 'node_2': 'carbonate reservoir', 'edge': 'is in'}, {'node_1': 'Ki Lan discovery', 'node_2': 'northern part of the basin', 'edge': 'is in'}, {'node_1': 'Blue Whale discovery', 'node_2': 'middle Miocene carbonate', 'edge': 'is in'}, {'node_1': 'Ken Bau gas discovery', 'node_2': 'late Miocene trap', 'edge': 'is in'}]
# .[{'node_1': 'Sông Hồng Basin', 'node_2': 'potential research', 'edge': 'comprises'}, {'node_1': 'Sông Hồng Basin', 'node_2': 'PetroVietnam Institute of Petroleum', 'edge': 'commissioned task'}, {'node_1': 'topic', 'node_2': 'results of geological-geophysical research', 'edge': 'includes'}, {'node_1': 'topic', 'node_2': 'data set', 'edge': 'updates'}, {'node_1': 'topic', 'node_2': 'summarizes the potential oil and gas reserves', 'edge': 'as of'}, {'node_1': 'research results', 'node_2': 'research level', 'edge': 'assesses'}, {'node_1': 'research results', 'node_2': 'existing issues', 'edge': 'assesses'}, {'node_1': 'research results', 'node_2': 'comprehensive geological picture', 'edge': 'prepares report to build'}, {'node_1': 'comprehensive geological picture', 'node_2': 'remaining potential', 'edge': 'assesses'}, {'node_1': 'comprehensive geological picture', 'node_2': 'direction for future research', 'edge': 'proposes'}]
# .[{'node_1': 'Bể Sông Hồng', 'node_2': 'địa lý', 'edge': 'nằm trong'}, {'node_1': 'Bể Sông Hồng', 'node_2': 'diện tích', 'edge': 'có'}, {'node_1': 'Bể Sông Hồng', 'node_2': 'đá móng lộ thiên Mesozoi – Paleozoi', 'edge': 'là'}, {'node_1': 'Bể Sông Hồng', 'node_2': 'đá móng lộ thiên Mesozoi – Paleozoi đảo Hải Nam', 'edge': 'là'}, {'node_1': 'Bể Sông Hồng', 'node_2': 'độ sâu nước biển', 'edge': 'độ'}, {'node_1': 'Bể Sông Hồng', 'node_2': 'địa hình đáy biển', 'edge': 'thoải dần về'}, {'node_1': 'Bể Sông Hồng', 'node_2': 'mực nước', 'edge': 'thay đổi từ'}, {'node_1': 'Bể Sông Hồng', 'node_2': 'thăm dò địa chấn', 'edge': 'công tác'}, {'node_1': 'Bể Sông Hồng', 'node_2': 'nghiên cứu', 'edge': 'của đề tài từ'}, {'node_1': 'Bể Sông Hồng', 'node_2': 'lô 101', 'edge': 'từ'}]
# .[{'node_1': 'water', 'node_2': 'elevation', 'edge': 'varies from'}, {'node_1': 'exploration', 'node_2': 'seismic exploration', 'edge': 'related to'}, {'node_1': 'year 1980', 'node_2': 'exploration activity', 'edge': 'before'}, {'node_1': 'international oil company', 'node_2': 'oil exploration', 'edge': 'conducted'}, {'node_1': 'seismic network', 'node_2': 'central coastal area', 'edge': 'detonated from'}, {'node_1': '2D seismic survey', 'node_2': 'network', 'edge': 'has'}, {'node_1': 'year 1981', 'node_2': 'initiated', 'edge': 'truly started'}, {'node_1': 'Soviet Union', 'node_2': 'implemented', 'edge': 'assisted'}, {'node_1': 'Vietnam Oil and Gas Corporation', 'node_2': '2D seismic survey', 'edge': 'conducted'}, {'node_1': 'research line network', 'node_2': '16x16 km area', 'edge': 'belongs to'}]
# .[{'node_1': 'Block 102', 'node_2': '2x2 km grid network', 'edge': 'belongs to'}, {'node_1': 'Block 103', 'node_2': '2x2 km grid network', 'edge': 'belongs to'}, {'node_1': 'Block 106', 'node_2': '2x2 km grid network', 'edge': 'belongs to'}, {'node_1': 'Block 107', 'node_2': '2x2 km grid network', 'edge': 'belongs to'}, {'node_1': 'Block 106', 'node_2': '48 observation points', 'edge': 'at'}, {'node_1': 'Poisk seismic vessel', 'node_2': 'Former Soviet Union', 'edge': 'of'}, {'node_1': 'Iskachel seismic vessel', 'node_2': 'Former Soviet Union', 'edge': 'of'}, {'node_1': 'Geological structure map', 'node_2': 'thickness assessment', 'edge': 'enables'}, {'node_1': 'Geological structure map', 'node_2': 'mainly structural and tectonic factors', 'edge': 'enables'}, {'node_1': 'Third Formation sediment', 'node_2': 'Hanoi Trough Region (HTR)', 'edge': 'belongs to'}]
# .[{'node_1': 'Total', 'node_2': '2D seismic survey', 'edge': 'has conducted'}, {'node_1': 'Shell', 'node_2': '2D seismic survey', 'edge': 'has conducted'}, {'node_1': 'BP', 'node_2': 'seismic survey', 'edge': 'has conducted'}, {'node_1': 'Idemitsu', 'node_2': '2D seismic survey', 'edge': 'has conducted'}, {'node_1': 'SCEPTRE', 'node_2': 'seismic survey', 'edge': 'has conducted'}, {'node_1': 'IPL', 'node_2': 'seismic survey', 'edge': 'has conducted'}, {'node_1': 'GecoPrakla', 'node_2': 'seismic survey', 'edge': 'has conducted'}, {'node_1': 'PVN', 'node_2': 'seismic survey', 'edge': 'has conducted'}]
# .[{'node_1': 'PVN', 'node_2': 'seismic survey', 'edge': 'conducts'}, {'node_1': 'PCOSB', 'node_2': 'blocks 102, 106', 'edge': 'conducts 2D and 3D surveys'}, {'node_1': 'VN-TQ', 'node_2': 'joint exploration agreement', 'edge': 'signs'}, {'node_1': 'PIDC (PVEP)', 'node_2': 'survey', 'edge': 'conducts'}, {'node_1': 'VGP', 'node_2': 'seismic survey', 'edge': 'implements'}, {'node_1': 'ExxonMobil', 'node_2': 'detonates', 'edge': '3D seismic survey'}, {'node_1': 'ExxonMobil', 'node_2': 'reprocesses', 'edge': '30 lines of 2D seismic survey'}, {'node_1': 'PVN', 'node_2': '2D seismic survey', 'edge': 'conducts'}, {'node_1': 'PVN', 'node_2': '2D seismic survey', 'edge': 'conducts'}, {'node_1': 'PVN', 'node_2': '2D seismic survey', 'edge': 'conducts'}]
# .[{'node_1': 'Sông Hồng Basin', 'node_2': 'exploration lines', 'edge': 'has'}, {'node_1': 'Sông Hồng Basin', 'node_2': 'total of 59 exploration wells', 'edge': 'has'}, {'node_1': 'exploration well', 'node_2': 'targeting Reservoir A', 'edge': 'has'}, {'node_1': 'exploration well', 'node_2': 'targeting Pliocene to Oligocene sandstone and Miocene carbonate', 'edge': 'has'}, {'node_1': 'CNOOC', 'node_2': 'drilled 2 exploration wells Weizhou 14-2-1 and Weizhou 14-2-2', 'edge': 'has'}, {'node_1': 'Weizhou 14-2-1 well', 'node_2': 'discovered gas in the ancient third member mudstone', 'edge': 'has'}, {'node_1': 'Weizhou 14-2-1 well', 'node_2': 'effective gas-bearing thickness of about 7.5 m', 'edge': 'has'}, {'node_1': 'Total', 'node_2': 'drilled 03 exploration wells: 103T-H-1X, 103T-G-1X, and 107T-PA-1X', 'edge': 'has'}, {'node_1': '103T-H-1X well', 'node_2': 'discovered in the Middle-Lower Miocene sandstone and sandstone conglomerate', 'edge': 'has'}, {'node_1': '107T-PA-1X well', 'node_2': 'did not discover hydrocarbons', 'edge': 'does not have'}]
# .[{'node_1': 'well 107T-PA-1X', 'node_2': 'petroleum', 'edge': 'not detected'}, {'node_1': 'well 102-CQ-1X', 'node_2': 'petroleum', 'edge': 'detected in Mioxen - Oligoxen formation'}, {'node_1': 'well 102-HD-1X', 'node_2': 'petroleum', 'edge': 'detected in Mioxen - Oligoxen formation'}, {'node_1': 'well 103-HOL-1X', 'node_2': 'weak gas flow', 'edge': 'tested reservoir'}, {'node_1': 'well 107-BAL-1X', 'node_2': 'large gas flow', 'edge': 'detected from sand formations'}, {'node_1': 'Bạch Đằng Petroleum Exploration Production', 'node_2': 'gas-condensate, dry gas reservoirs', 'edge': 'detected in Mioxen Giữa formation'}, {'node_1': 'well 103-HAL-1X', 'node_2': 'gas-condensate, dry gas reservoirs', 'edge': 'detected in Hắc Long formation'}, {'node_1': 'well 103-DL-1X', 'node_2': 'gas-condensate, dry gas reservoirs', 'edge': 'detected in Địa Long formation'}, {'node_1': 'Bạch Đằng Petroleum Exploration Production', 'node_2': 'well 107-PL-1X', 'edge': 'drilled'}]
# .[{'node_1': 'depth 3.201m', 'node_2': 'gas-condensate reservoir', 'edge': 'discovered'}, {'node_1': 'gas-condensate reservoir', 'node_2': 'dry gas', 'edge': 'found in'}, {'node_1': 'PVEP', 'node_2': 'well 107-PL-1X', 'edge': 'drilled'}, {'node_1': 'PVEP', 'node_2': 'GK 107-Kỳ Lân-1X', 'edge': 'drilled'}, {'node_1': 'GK 107-Kỳ Lân-1X', 'node_2': 'Mioxen Upper, Mioxen Middle', 'edge': 'sandstone formations'}, {'node_1': 'GK 107-Kỳ Lân-1X', 'node_2': 'gas', 'edge': 'discovered in'}, {'node_1': 'GK 107-Kỳ Lân-1X', 'node_2': 'DST#1', 'edge': 'tested'}, {'node_1': 'GK 107-Kỳ Lân-1X', 'node_2': 'DST#2', 'edge': 'tested'}, {'node_1': 'GK 102-TB-1X', 'node_2': 'gas-condensate reservoir', 'edge': 'received'}, {'node_1': 'GK 106-YT-1X', 'node_2': 'crude oil signs', 'edge': 'detected at'}]
# .[{'node_1': 'Mioxen Giữa', 'node_2': 'dấu hiệu dầu thô', 'edge': 'indicates'}, {'node_1': 'Mioxen Giữa', 'node_2': 'dấu hiệu dầu khí', 'edge': 'indicates'}, {'node_1': 'Móng đá vôi', 'node_2': 'thiếu vắng trầm tích Oligoxen', 'edge': 'due to'}, {'node_1': 'Hàm Rồng', 'node_2': 'Móng đá vôi', 'edge': 'constitutes'}, {'node_1': 'GK 106-DS-1X', 'node_2': 'Móng đá vôi', 'edge': 'detects oil'}, {'node_1': 'PVEP', 'node_2': 'Lô 102/10&106/10', 'edge': 'operates'}, {'node_1': 'PVEP', 'node_2': 'HRN-1X', 'edge': 'conducts drilling'}, {'node_1': 'PVEP', 'node_2': 'SP-1X', 'edge': 'conducts drilling'}]
# .[{'node_1': 'Exploration Block 102/10&106/10, PVEP', 'node_2': 'HRN-1X Well', 'edge': 'drilling operation'}, {'node_1': 'Exploration Block 102/10&106/10, PVEP', 'node_2': 'SP-1X Well', 'edge': 'drilling operation'}, {'node_1': 'HRN-1X Well', 'node_2': 'Hàm Rồng Đông Formation', 'edge': 'evaluated as prospective for hydrocarbons'}, {'node_1': 'SP-1X Well', 'node_2': 'completion', 'edge': 'immediately after'}, {'node_1': '106/10-HRN-1X Well', 'node_2': 'Móng Cacbonat Rock', 'edge': 'rock type'}, {'node_1': '106/10-HRN-1X Well', 'node_2': 'well depth', 'edge': 'achieved'}, {'node_1': '106/10-HRN-1X Well', 'node_2': 'maximum flow rate', 'edge': 'flow rate'}, {'node_1': '106/10-HRN-1X Well', 'node_2': 'condensate barrels', 'edge': 'flow rate'}, {'node_1': '102/10-SP-1X Well', 'node_2': 'Oligoxen-Mioxen Sandstone', 'edge': 'rock type'}, {'node_1': '106/10-HRD-1X Well', 'node_2': 'Móng Cacbonat Rock', 'edge': 'rock type'}]
# .[{'node_1': 'carbon dioxide (CO2)', 'node_2': 'hydrogen sulfide (H2S)', 'edge': 'coexists with'}, {'node_1': 'carbonate reservoir', 'node_2': 'well', 'edge': 'is tested in'}, {'node_1': 'well', 'node_2': 'gas flow rate', 'edge': 'has maximum'}, {'node_1': 'well', 'node_2': 'condensate barrels', 'edge': 'has'}, {'node_1': 'Hạ Mai-1X well', 'node_2': 'Santos contractor', 'edge': 'is drilled by'}, {'node_1': 'Hạ Mai-1X well', 'node_2': 'exploration', 'edge': 'is exploration of'}, {'node_1': 'Hạ Mai-1X well', 'node_2': '2009', 'edge': 'is drilled in'}, {'node_1': 'Hạ Mai-1X well', 'node_2': '4 gas reservoirs', 'edge': 'has'}, {'node_1': 'Hạ Mai-1X well', 'node_2': 'log interpretation data', 'edge': 'results in'}, {'node_1': 'Santos contractor', 'node_2': 'Slamander contractor', 'edge': 'is contractor with'}]
# .[{'node_1': 'Sông Hồng', 'node_2': 'bể', 'edge': 'is located in'}, {'node_1': 'Shell', 'node_2': 'exploration wells', 'edge': 'performs'}, {'node_1': 'exploration well 112-BT-1X', 'node_2': 'incident', 'edge': 'encounters'}, {'node_1': 'exploration well 112-BT-1XRDR', 'node_2': 'gas in Oligocene - Miocene sandstone', 'edge': 'contains'}, {'node_1': 'OMV', 'node_2': 'exploration well GK 111-HE-1X', 'edge': 'drills'}, {'node_1': 'VGP JOC', 'node_2': 'exploration well 113-BD-1X', 'edge': 'conducts'}, {'node_1': 'VGP JOC', 'node_2': 'exploration well 113-BV-1X', 'edge': 'conducts'}, {'node_1': 'exploration well 113-BV-1X', 'node_2': 'Bao Vang gas', 'edge': 'discovers'}, {'node_1': 'exploration well 113-BV-1X', 'node_2': 'total of 2 gas reservoirs', 'edge': 'tests with'}, {'node_1': 'phase 2', 'node_2': 'exploration well 111-BV-2X', 'edge': 'conducts'}]
# .[{'node_1': 'Gas Reservoir', 'node_2': 'gas flow rate', 'edge': 'has'}, {'node_1': 'Coal Reservoir', 'node_2': 'flow', 'edge': 'yields'}, {'node_1': 'Oil Reservoir', 'node_2': 'CO2 content', 'edge': 'high'}, {'node_1': 'Production Sharing Contract', 'node_2': 'Eni, Chrisenergy, Neon', 'edge': 'between'}, {'node_1': 'Well 105-CL-1X', 'node_2': 'August 2013', 'edge': 'drilled in'}, {'node_1': 'Well 105-CL-1X', 'node_2': 'flow', 'edge': 'has'}, {'node_1': 'Well 105-CL-1X', 'node_2': 'depth 2399-2437mMD', 'edge': 'at'}, {'node_1': 'Well 105-CL-1X', 'node_2': '0.4 MMcf/d', 'edge': 'low'}, {'node_1': 'ENI', 'node_2': 'GK 114-Kèn Bầu-1X', 'edge': 'contractor for drilling'}, {'node_1': 'GK 114-Kèn Bầu-1X', 'node_2': 'well bottom depth', 'edge': 'reached'}, {'node_1': 'drilling well', 'node_2': 'commercial gas', 'edge': 'has discovery'}, {'node_1': 'Red River Basin', 'node_2': 'exploration and exploitation of oil and gas', 'edge': 'Operates'}, {'node_1': 'Vietnam Oil and Gas Group', 'node_2': 'Vietnam National Oil and Gas Group', 'edge': 'later known as'}]
# .[{'node_1': 'drilling well', 'node_2': 'formation', 'edge': 'evaluated at'}, {'node_1': 'contractor', 'node_2': 'drilling well', 'edge': 'performed'}, {'node_1': 'drilling well', 'node_2': 'exploration', 'edge': 'has been conducted'}, {'node_1': 'drilling well', 'node_2': 'commercial result', 'edge': 'achieved'}, {'node_1': 'operator', 'node_2': 'exploration drilling', 'edge': 'carried out'}, {'node_1': 'operator', 'node_2': 'drilling well', 'edge': 'conducted'}, {'node_1': 'result', 'node_2': 'gas field', 'edge': 'discovered'}, {'node_1': 'drilling well', 'node_2': 'limestone layer', 'edge': 'entered'}, {'node_1': 'ENI', 'node_2': 'drilling well', 'edge': 'drilled'}, {'node_1': 'seismic data', 'node_2': 'interpretation', 'edge': 'survey and'}]
# .[{'node_1': 'ENI drilling well 120-CV-1X', 'node_2': 'limestone formation', 'edge': 'penetrates'}, {'node_1': 'ENI drilling well 120-CV-1X', 'node_2': 'Tri Ton uplift belt', 'edge': 'penetrates'}, {'node_1': 'ENI drilling well 120-CV-1X', 'node_2': 'dry drilling result', 'edge': 'yields'}, {'node_1': 'survey', 'node_2': 'seismic data', 'edge': 'interprets'}, {'node_1': 'survey', 'node_2': 'entire Song Hong basin area', 'edge': 'is conducted on'}, {'node_1': 'survey', 'node_2': "Vietnam's national waters", 'edge': 'is conducted by'}, {'node_1': 'survey', 'node_2': 'foreign contractors', 'edge': 'is conducted by'}, {'node_1': 'seismic activity', 'node_2': 'entire Song Hong basin area', 'edge': 'has'}, {'node_1': 'seismic activity', 'node_2': 'approximately 1.850.819km 2D seismic lines', 'edge': 'has'}, {'node_1': '2D PVN-12 and PVN-15 survey', 'node_2': 'area lines for research purposes', 'edge': 'has supplemented'}]
# .[{'node_1': 'geological survey area', 'node_2': 'Northern and Eastern Phu Khanh Basin area', 'edge': 'linked to'}, {'node_1': 'survey density', 'node_2': '0.65 km/km2', 'edge': 'achieves'}, {'node_1': 'seismic line density', 'node_2': 'uneven', 'edge': 'most concentrated in'}, {'node_1': 'Northern basin area', 'node_2': 'blocks 102, 103, 106, 107', 'edge': 'most concentrated in'}, {'node_1': 'central area', 'node_2': 'blocks 112, 113, and 114', 'edge': 'most concentrated in'}, {'node_1': '3D seismic survey', 'node_2': '15,000 km2', 'edge': 'achieves'}, {'node_1': '3D seismic data', 'node_2': 'reference data', 'edge': 'acts as'}, {'node_1': 'seismic data quality', 'node_2': 'evolves with advancing technology', 'edge': 'changes due to'}, {'node_1': 'previously acquired and processed seismic data', 'node_2': 'average quality', 'edge': 'has'}, {'node_1': '2D seismic data', 'node_2': 'interpret and link areas', 'edge': 'is used to'}]
# .[{'node_1': '2D seismic data', 'node_2': 'interpretation', 'edge': 'is used for'}, {'node_1': '2D seismic data', 'node_2': 'regional correlation', 'edge': 'is used for'}, {'node_1': '3D seismic data', 'node_2': 'prospective structures', 'edge': 'covers'}, {'node_1': '3D seismic data', 'node_2': 'acquisition and processing', 'edge': 'is used for'}, {'node_1': 'seismic acquisition company', 'node_2': 'positioning system', 'edge': 'at'}, {'node_1': 'seismic acquisition company', 'node_2': 'projection system', 'edge': 'at'}, {'node_1': 'seismic data', 'node_2': 'common positioning system', 'edge': 'is converted to'}, {'node_1': 'seismic data', 'node_2': 'projection system', 'edge': 'is converted to'}, {'node_1': 'seismic data', 'node_2': 'coordinate system', 'edge': 'is transformed to'}, {'node_1': 'seismic data', 'node_2': 'phase and time discrepancies', 'edge': 'have'}]
# (189, 5)
#                         node_1                       node_2              edge  \
# 0  sông hồng sedimentary basin                     kainozoi      is a type of
# 1  sông hồng sedimentary basin                    petroleum          contains
# 2    vietnam oil and gas group  sông hồng sedimentary basin  is interested in
# 3  sông hồng sedimentary basin           ham rong discovery               has
# 4  sông hồng sedimentary basin             ki lan discovery               has
#
#                            chunk_id  count
# 0  2b796e4335064983a21222b4251d11e9      4
# 1  2b796e4335064983a21222b4251d11e9      4
# 2  2b796e4335064983a21222b4251d11e9      4
# 3  2b796e4335064983a21222b4251d11e9      4
# 4  2b796e4335064983a21222b4251d11e9      4

# %%
dfg1
# Out:
#                           node_1                        node_2  \
# 0    sông hồng sedimentary basin                      kainozoi
# 1    sông hồng sedimentary basin                     petroleum
# 2      vietnam oil and gas group   sông hồng sedimentary basin
# 3    sông hồng sedimentary basin            ham rong discovery
# 4    sông hồng sedimentary basin              ki lan discovery
# ..                           ...                           ...
# 184  seismic acquisition company             projection system
# 185                 seismic data     common positioning system
# 186                 seismic data             projection system
# 187                 seismic data             coordinate system
# 188                 seismic data  phase and time discrepancies
#
#                   edge                          chunk_id  count
# 0         is a type of  2b796e4335064983a21222b4251d11e9      4
# 1             contains  2b796e4335064983a21222b4251d11e9      4
# 2     is interested in  2b796e4335064983a21222b4251d11e9      4
# 3                  has  2b796e4335064983a21222b4251d11e9      4
# 4                  has  2b796e4335064983a21222b4251d11e9      4
# ..                 ...                               ...    ...
# 184                 at  885ae2861dad4d389009d4992a896e5b      4
# 185    is converted to  885ae2861dad4d389009d4992a896e5b      4
# 186    is converted to  885ae2861dad4d389009d4992a896e5b      4
# 187  is transformed to  885ae2861dad4d389009d4992a896e5b      4
# 188               have  885ae2861dad4d389009d4992a896e5b      4
#
# [189 rows x 5 columns]

# %% [markdown]
# ## Calculating contextual proximity

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    ## Melt the dataframe into a list of nodes
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    # Self join with chunk id as the key will create a link between terms occuring in the same text chunk.
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    # drop self loops
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    ## Group and count edges.
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    # Drop edges with 1 count
    dfg2 = dfg2[dfg2["count"] != 1]
    dfg2["edge"] = "contextual proximity"
    return dfg2


dfg2 = contextual_proximity(dfg1)
dfg2.tail()
# Out:
#                                                node_1        node_2  \
# 3652              đá móng lộ thiên mesozoi – paleozoi  bể sông hồng
# 3662  đá móng lộ thiên mesozoi – paleozoi đảo hải nam  bể sông hồng
# 3672                                địa hình đáy biển  bể sông hồng
# 3682                                           địa lý  bể sông hồng
# 3692                                 độ sâu nước biển  bể sông hồng
#
#                                                chunk_id  count  \
# 3652  78f3613f808c40b59f9ff520584b8cfe,78f3613f808c4...     10
# 3662  78f3613f808c40b59f9ff520584b8cfe,78f3613f808c4...     10
# 3672  78f3613f808c40b59f9ff520584b8cfe,78f3613f808c4...     10
# 3682  78f3613f808c40b59f9ff520584b8cfe,78f3613f808c4...     10
# 3692  78f3613f808c40b59f9ff520584b8cfe,78f3613f808c4...     10
#
#                       edge
# 3652  contextual proximity
# 3662  contextual proximity
# 3672  contextual proximity
# 3682  contextual proximity
# 3692  contextual proximity

# %% [markdown]
# ### Merge both the dataframes

# %%
dfg = pd.concat([dfg1, dfg2], axis=0)
dfg = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)
dfg
# Out:
#                                                node_1  \
# 0                                          0.4 mmcf/d
# 1                                          0.4 mmcf/d
# 2                                          0.4 mmcf/d
# 3                                   102/10-sp-1x well
# 4                                   102/10-sp-1x well
# ...                                               ...
# 1322              đá móng lộ thiên mesozoi – paleozoi
# 1323  đá móng lộ thiên mesozoi – paleozoi đảo hải nam
# 1324                                địa hình đáy biển
# 1325                                           địa lý
# 1326                                 độ sâu nước biển
#
#                                      node_2  \
# 0                                      flow
# 1                         gk 114-kèn bầu-1x
# 2                            well 105-cl-1x
# 3                        106/10-hrn-1x well
# 4     exploration block 102/10&106/10, pvep
# ...                                     ...
# 1322                           bể sông hồng
# 1323                           bể sông hồng
# 1324                           bể sông hồng
# 1325                           bể sông hồng
# 1326                           bể sông hồng
#
#                                                chunk_id                  edge  \
# 0     a525c1c6d8e845319952801092a2d426,a525c1c6d8e84...  contextual proximity
# 1     a525c1c6d8e845319952801092a2d426,a525c1c6d8e84...  contextual proximity
# 2     a525c1c6d8e845319952801092a2d426,a525c1c6d8e84...  contextual proximity
# 3     8ea238aabedf45fb8d685ea666b54b54,8ea238aabedf4...  contextual proximity
# 4     8ea238aabedf45fb8d685ea666b54b54,8ea238aabedf4...  contextual proximity
# ...                                                 ...                   ...
# 1322  78f3613f808c40b59f9ff520584b8cfe,78f3613f808c4...  contextual proximity
# 1323  78f3613f808c40b59f9ff520584b8cfe,78f3613f808c4...  contextual proximity
# 1324  78f3613f808c40b59f9ff520584b8cfe,78f3613f808c4...  contextual proximity
# 1325  78f3613f808c40b59f9ff520584b8cfe,78f3613f808c4...  contextual proximity
# 1326  78f3613f808c40b59f9ff520584b8cfe,78f3613f808c4...  contextual proximity
#
#       count
# 0         2
# 1         2
# 2         4
# 3         4
# 4         2
# ...     ...
# 1322     10
# 1323     10
# 1324     10
# 1325     10
# 1326     10
#
# [1327 rows x 5 columns]

# %% [markdown]
# ## Calculate the NetworkX Graph

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape
# Out:
# (245,)

# %%
pip install networkx
# Out:
# Collecting networkx
#   Obtaining dependency information for networkx from https://files.pythonhosted.org/packages/38/e9/5f72929373e1a0e8d142a130f3f97e6ff920070f87f91c4e13e40e0fba5a/networkx-3.3-py3-none-any.whl.metadata
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    - -------------------------------------- 0.1/1.7 MB 1.1 MB/s eta 0:00:02
#    ------ --------------------------------- 0.3/1.7 MB 2.3 MB/s eta 0:00:01
#    --------------- ------------------------ 0.7/1.7 MB 4.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.1/1.7 MB 5.5 MB/s eta 0:00:01
#    -------------------------------------- - 1.6/1.7 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 6.4 MB/s eta 0:00:00
# Installing collected packages: networkx
# Successfully installed networkx-3.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import networkx as nx
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/4
    )

# %% [markdown]
# ### Calculate communities for coloring the nodes

# %%
communities_generator = nx.community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)
# Out:
# Number of Communities =  13
# [['0.4 mmcf/d', '102/10-sp-1x well', '106/10-hrd-1x well', '106/10-hrn-1x well', '2009', '4 gas reservoirs', 'august 2013', 'blue whale discovery', 'bạch đằng petroleum exploration production', 'carbon dioxide (co2)', 'carbonate reservoir', 'co2 content', 'coal reservoir', 'commercial gas', 'commercial result', 'completion', 'condensate barrels', 'contractor', 'crude oil signs', 'depth 2399-2437mmd', 'depth 3.201m', 'drilling well', 'dry gas', 'dst#1', 'dst#2', 'dấu hiệu dầu khí', 'dấu hiệu dầu thô', 'eni', 'eni, chrisenergy, neon', 'exploration', 'exploration and exploitation of oil and gas', 'exploration block 102/10&106/10, pvep', 'exploration drilling', 'flow', 'formation', 'gas', 'gas field', 'gas flow rate', 'gas reservoir', 'gas-condensate reservoir', 'gas-condensate, dry gas reservoirs', 'gk 102-tb-1x', 'gk 106-ds-1x', 'gk 106-yt-1x', 'gk 107-kỳ lân-1x', 'gk 114-kèn bầu-1x', 'ham rong discovery', 'hrn-1x', 'hrn-1x well', 'hydrogen sulfide (h2s)', 'hàm rồng', 'hàm rồng đông formation', 'hạ mai-1x well', 'kainozoi', 'ken bau gas discovery', 'ki lan discovery', 'large gas flow', 'late miocene trap', 'limestone layer', 'log interpretation data', 'lô 102/10&106/10', 'maximum flow rate', 'middle miocene carbonate', 'mioxen giữa', 'mioxen upper, mioxen middle', 'móng cacbonat rock', 'móng đá vôi', 'northern part of the basin', 'oil reservoir', 'oligoxen-mioxen sandstone', 'operator', 'petroleum', 'production sharing contract', 'pvep', 'red river basin', 'result', 'santos contractor', 'slamander contractor', 'sp-1x', 'sp-1x well', 'sông hồng sedimentary basin', 'thiếu vắng trầm tích oligoxen', 'vietnam national oil and gas group', 'vietnam oil and gas group', 'weak gas flow', 'well', 'well 102-cq-1x', 'well 102-hd-1x', 'well 103-dl-1x', 'well 103-hal-1x', 'well 103-hol-1x', 'well 105-cl-1x', 'well 107-bal-1x', 'well 107-pl-1x', 'well 107t-pa-1x', 'well bottom depth', 'well depth'], ['0.65 km/km2', 'survey density'], ['103t-h-1x well', '107t-pa-1x well', 'cnooc', 'comprehensive geological picture', 'data set', 'did not discover hydrocarbons', 'direction for future research', 'discovered gas in the ancient third member mudstone', 'discovered in the middle-lower miocene sandstone and sandstone conglomerate', 'drilled 03 exploration wells: 103t-h-1x, 103t-g-1x, and 107t-pa-1x', 'drilled 2 exploration wells weizhou 14-2-1 and weizhou 14-2-2', 'effective gas-bearing thickness of about 7.5 m', 'existing issues', 'exploration lines', 'exploration well', 'petrovietnam institute of petroleum', 'potential research', 'remaining potential', 'research level', 'research results', 'results of geological-geophysical research', 'summarizes the potential oil and gas reserves', 'sông hồng basin', 'targeting pliocene to oligocene sandstone and miocene carbonate', 'targeting reservoir a', 'topic', 'total', 'total of 59 exploration wells', 'weizhou 14-2-1 well'], ['15,000 km2', '3d seismic survey'], ['16x16 km area', '2d pvn-12 and pvn-15 survey', '2d seismic data', '2d seismic survey', '3d seismic data', 'acquisition and processing', 'approximately 1.850.819km 2d seismic lines', 'area lines for research purposes', 'bao vang gas', 'blocks 102, 106', 'bp', 'bể', 'central coastal area', 'common positioning system', 'coordinate system', 'detonates', 'dry drilling result', 'elevation', 'eni drilling well 120-cv-1x', 'entire song hong basin area', 'exploration activity', 'exploration well 111-bv-2x', 'exploration well 112-bt-1x', 'exploration well 112-bt-1xrdr', 'exploration well 113-bd-1x', 'exploration well 113-bv-1x', 'exploration well gk 111-he-1x', 'exploration wells', 'exxonmobil', 'foreign contractors', 'gas in oligocene - miocene sandstone', 'gecoprakla', 'idemitsu', 'implemented', 'incident', 'initiated', 'international oil company', 'interpret and link areas', 'interpretation', 'ipl', 'joint exploration agreement', 'limestone formation', 'network', 'oil exploration', 'omv', 'pcosb', 'phase 2', 'phase and time discrepancies', 'pidc (pvep)', 'pos ...

# %% [markdown]
# ### Create a dataframe for community colors

# %%
pip install pyvis
# Out:
# Collecting pyvis
#   Obtaining dependency information for pyvis from https://files.pythonhosted.org/packages/ab/4b/e37e4e5d5ee1179694917b445768bdbfb084f5a59ecd38089d3413d4c70f/pyvis-0.3.2-py3-none-any.whl.metadata
#   Downloading pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: ipython>=5.3.0 in d:\knowledgegraph\kg_venv\lib\site-packages (from pyvis) (8.23.0)
# Collecting jinja2>=2.9.6 (from pyvis)
#   Obtaining dependency information for jinja2>=2.9.6 from https://files.pythonhosted.org/packages/30/6d/6de6be2d02603ab56e72997708809e8a5b0fbfee080735109b40a3564843/Jinja2-3.1.3-py3-none-any.whl.metadata
#   Using cached Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting jsonpickle>=1.4.1 (from pyvis)
#   Obtaining dependency information for jsonpickle>=1.4.1 from https://files.pythonhosted.org/packages/19/c3/453e4e2da82d5efad9e653916a120d94daf5062f7eae43e28f39fff1bc6a/jsonpickle-3.0.4-py3-none-any.whl.metadata
#   Downloading jsonpickle-3.0.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: networkx>=1.11 in d:\knowledgegraph\kg_venv\lib\site-packages (from pyvis) (3.3)
# Requirement already satisfied: decorator in d:\knowledgegraph\kg_venv\lib\site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\knowledgegraph\kg_venv\lib\site-packages (from ipython>=5.3.0->pyvis) (0.19.1)
# Requirement already satisfied: matplotlib-inline in d:\knowledgegraph\kg_venv\lib\site-packages (from ipython>=5.3.0->pyvis) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in d:\knowledgegraph\kg_venv\lib\site-packages (from ipython>=5.3.0->pyvis) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in d:\knowledgegraph\kg_venv\lib\site-packages (from ipython>=5.3.0->pyvis) (2.17.2)
# Requirement already satisfied: stack-data in d:\knowledgegraph\kg_venv\lib\site-packages (from ipython>=5.3.0->pyvis) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in d:\knowledgegraph\kg_venv\lib\site-packages (from ipython>=5.3.0->pyvis) (5.14.2)
# Requirement already satisfied: typing-extensions in d:\knowledgegraph\kg_venv\lib\site-packages (from ipython>=5.3.0->pyvis) (4.11.0)
# Requirement already satisfied: colorama in d:\knowledgegraph\kg_venv\lib\site-packages (from ipython>=5.3.0->pyvis) (0.4.6)
# Collecting MarkupSafe>=2.0 (from jinja2>=2.9.6->pyvis)
#   Obtaining dependency information for MarkupSafe>=2.0 from https://files.pythonhosted.org/packages/b7/a2/c78a06a9ec6d04b3445a949615c4c7ed86a0b2eb68e44e7541b9d57067cc/MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl.metadata
#   Using cached MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in d:\knowledgegraph\kg_venv\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.4)
# Requirement already satisfied: wcwidth in d:\knowledgegraph\kg_venv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in d:\knowledgegraph\kg_venv\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\knowledgegraph\kg_venv\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.4.1)
# Requirement already satisfied: pure-eval in d:\knowledgegraph\kg_venv\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in d:\knowledgegraph\kg_venv\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=5.3.0->pyvis) (1.16.0)
# Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#    ---------------------------------------- 0.0/756.0 kB ? eta -:--:--
#     --------------------------------------- 10.2/756.0 kB ? eta -:--:--
#    - -------------------------------------- 30.7/756.0 kB 1.3 MB/s eta 0:00:01
#    - -------------------------------------- 30.7/756.0 kB 1.3 MB/s eta 0:00:01
#    --- ----------------------------------- 61.4/756.0 kB 409.6 kB/s eta 0:00:02
#    ---------- ----------------------------- 204.8/756.0 kB 1.0 MB/s eta 0:00:01
#    -------------------- ------------------- 389.1/756.0 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 655.4/756.0 kB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 756.0/756.0 kB 2.5 MB/s eta 0:00:00
# Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Downloading jsonpickle-3.0.4-py3-none-any.whl (39 kB)
# Using cached MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl (17 kB)
# Installing collected packages: MarkupSafe, jsonpickle, jinja2, pyvis
# Successfully installed MarkupSafe-2.1.5 jinja2-3.1.3 jsonpickle-3.0.4 pyvis-0.3.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
palette = "hls"

## Now add these colors to communities and make another dataframe
def colors2Community(communities) -> pd.DataFrame:
    ## Define a color palette
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors


colors = colors2Community(communities)
colors
# Out:
#                                           node    color  group
# 0                                   0.4 mmcf/d  #63db57      1
# 1                            102/10-sp-1x well  #63db57      1
# 2                           106/10-hrd-1x well  #63db57      1
# 3                           106/10-hrn-1x well  #63db57      1
# 4                                         2009  #63db57      1
# ..                                         ...      ...    ...
# 240                       seismic data quality  #57b5db     11
# 241                     geological survey area  #7357db     12
# 242  northern and eastern phu khanh basin area  #7357db     12
# 243                       seismic line density  #dbd957     13
# 244                                     uneven  #dbd957     13
#
# [245 rows x 3 columns]

# %% [markdown]
# ### Add colors to the graph

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
from pyvis.network import Network

graph_output_directory = "./docs/index.html"

net = Network(
    notebook=False,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)
net.show_buttons(filter_=["physics"])

net.show(graph_output_directory, notebook=False)
# Out:
# ./docs/index.html
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[22], line 22
#      19 # net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)
#      20 net.show_buttons(filter_=["physics"])
# ---> 22 net.show(graph_output_directory, notebook=False)
#
# File d:\KnowledgeGraph\KG_venv\Lib\site-packages\pyvis\network.py:548, in Network.show(self, name, local, notebook)
#     546     self.write_html(name, open_browser=False,notebook=True)
#     547 else:
# --> 548     self.write_html(name, open_browser=True)
#     549 if notebook:
#     550     return IFrame(name, width=self.width, height=self.height)
#
# File d:\KnowledgeGraph\KG_venv\Lib\site-packages\pyvis\network.py:530, in Network.write_html(self, name, local, notebook, open_browser)
#     528 elif self.cdn_resources == "in_line" or self.cdn_resources == "remote":
#     529     with open(getcwd_name, "w+") as out:
# --> 530         out.write(self.html)
#     531 else:
#     532     assert "cdn_resources is not in ['in_line','remote','local']."
#
# File ~\anaconda3\Lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u1ea7' in position 13237: character maps to <undefined>
